# %% [markdown]
# The feature selection notebook does a filter followed by a wrapper. It's capable of doing the filter on more than one file. The variable files are called vars1.csv, vars2.csv ...
#
# The filter runs separately on each vars file and keeps the top num_filter variables from each file. If there are more than one vars files we'll again select the top num_filter variables across all the vars.csv files.
#
# If balance = 0 the entire files are used. If balance != 0 then balance is the ratio of goods to bads retained for the rest of the feature selection. We keep all the rare class (bads) and downsample the goods.
#
# BUT RIGHT NOW I'VE GOT A BUG SOMEWHERE: balance !=0 doesn't work when num_files > 1. I've got an index problem.
#
# So you can run with multiple variables files only when balance=0, or you can run with only one variable file and set balance how you like.

# %%
# load libraries
# %pip install mlxtend

import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import datetime as dt
import gc
from sklearn.ensemble import RandomForestClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
# %matplotlib inline
start_time = dt.datetime.now()

# %%
# set some parameters
num_files = 1
num_filter = 100
num_wrapper = 30
# keep balance = 0 when num_files > 1 until I figure out this bug. Maybe somebody else can figure it out.
balance = 0
detect_rate = .03
index_name = 'record'
y_name = 'fraud_label'
good_label = 0
bad_label = 1

# %% [markdown]
# ## Run a filter on all the files

# %%
# %%time
for i in range(num_files):
    file_name = "vars.csv“
    df = pd.read_csv(file_name)
    print('work on file ', file_name)
    df = df[df[index_name] <= 833508] # remove the last two months as the out-of-time data (OOT)
    df = df[df[index_name] >= 38512] # remove the first 2 weeks of records since their variables aren't well formed
    df['RANDOM'] = np.random.ranf(len(df)) # add a random number variable to make sure it doesn't come up as important
    goods = df[df[y_name] == good_label]
    bads = df[df[y_name] == bad_label]
    del df # don't need this file anymore
    num_goods = len(goods)
    num_bads = len(bads)
    num_vars = len(bads.columns)-2
    if(balance != 0):
        if(i == 0):
            num_goods_desired = int(min(num_goods,num_bads*balance))
            goods = goods.sample(n=num_goods_desired,random_state=1)
            goods_keep = list(goods.index)
            goods_keep.sort()
    
        if(i > 0):
            goods.set_index(index_name, inplace=True)
            goods.sort_index(inplace=True)
            goods = goods.iloc[goods_keep] # THERE'S SOMETHING WRONG HERE AND I CAN'T FIGURE IT OUT
    
    df_sampled = pd.concat([goods,bads])
    df_sampled.set_index(index_name, inplace=True)
    df_sampled.sort_index(inplace=True)
    if(i == 0): # if first time through need to initialize some stuff
        Y = pd.DataFrame(df_sampled[y_name], index=df_sampled.index)
        filter_score = pd.DataFrame(np.zeros((num_vars+1,2)))
        filter_score.columns = ['variable','score']   
        j = 0
        for column in df_sampled:
            filter_score.loc[j,'variable'] = column
            filter_score.loc[j,'score'] = sps.ks_2samp(goods[column],bads[column])[0]
            j = j+1
            
        filter_score.sort_values(by=['score'], ascending=False, inplace=True)
        vars_keep = list(filter_score['variable'][1:num_filter+1])
        print(filter_score.head(num_filter))
        df_top = df_sampled.filter(vars_keep, axis=1)
            
    if(i > 0): # if more than one variable file we use this loop
        new = pd.DataFrame(np.zeros((num_vars+1,2)))
        new.columns = ['variable','score']   
        j = 0
        for column in df_sampled:
            new.loc[j,'variable'] = column
            new.loc[j,'score'] = sps.ks_2samp(goods[column],bads[column])[0]
            j = j+1
        
        new.sort_values(by=['score'], ascending=False, inplace=True)
        vars_keep = list(new['variable'][1:num_filter+1])
        print(new.head(num_filter))
        data_new_top = df_sampled.filter(vars_keep, axis=1)
        df_top = pd.concat([df_top,data_new_top], axis=1)
        filter_score = pd.concat([filter_score,new])
    
    del goods # delete these before starting the next file, if any
    del bads
    gc.collect()

# %%
filter_score.sort_values(by=['score'], ascending=False, inplace=True)

# %%
filter_score.to_excel('322.xlsx')

# %%
filter_score.head(28)
# Out:
#                             variable     score
# 9                        fraud_label  1.000000
# 45                 address_day_since  0.334096
# 73             fulladdress_day_since  0.333210
# 51                  address_count_30  0.332725
# 79              fulladdress_count_30  0.332032
# 50                  address_count_14  0.322252
# 78              fulladdress_count_14  0.321756
# 49                   address_count_7  0.301445
# 77               fulladdress_count_7  0.301368
# 238            address_count_0_by_30  0.291997
# 270        fulladdress_count_0_by_30  0.290783
# 237            address_count_0_by_14  0.281654
# 269        fulladdress_count_0_by_14  0.280601
# 76               fulladdress_count_3  0.278488
# 48                   address_count_3  0.278445
# 236             address_count_0_by_7  0.258716
# 268         fulladdress_count_0_by_7  0.258653
# 129      age_level_address_day_since  0.258346
# 135       age_level_address_count_30  0.257086
# 47                   address_count_1  0.249267
# 75               fulladdress_count_1  0.249083
# 134       age_level_address_count_14  0.246342
# 267         fulladdress_count_0_by_3  0.230647
# 235             address_count_0_by_3  0.230531
# 108  fulladdress_homephone_day_since  0.229995
# 114   fulladdress_homephone_count_30  0.228954
# 171                ssn_dob_day_since  0.228727
# 177                 ssn_dob_count_30  0.228512

# %%
filter_score.tail(10)
# Out:
#                                                variable  score
# 1863  ssn_age_level_homephone_unique_count_in_ssn_na...    0.0
# 1876  ssn_age_level_homephone_unique_count_in_ssn_na...    0.0
# 1877  ssn_age_level_homephone_unique_count_in_ssn_ag...    0.0
# 1878  ssn_age_level_homephone_unique_count_in_ssn_ag...    0.0
# 1879  ssn_age_level_homephone_unique_count_in_ssn_ag...    0.0
# 1880  ssn_age_level_homephone_unique_count_in_ssn_ag...    0.0
# 1881  ssn_age_level_homephone_unique_count_in_ssn_ag...    0.0
# 1882  ssn_age_level_homephone_unique_count_in_ssn_ag...    0.0
# 1874  ssn_age_level_homephone_unique_count_in_ssn_na...    0.0
# 942        dob_homephone_unique_count_in_ssn_zip5_for_3    0.0

# %%
filter_score.shape
# Out:
# (1884, 2)

# %%
filter_score.sort_values(by=['score'], ascending=False, inplace=True)
vars_keep = list(filter_score['variable'][num_files:num_filter+1])
print(i,' vars_keep:',vars_keep)
# Out:
# 0  vars_keep: ['address_day_since', 'fulladdress_day_since', 'address_count_30', 'fulladdress_count_30', 'address_count_14', 'fulladdress_count_14', 'address_count_7', 'fulladdress_count_7', 'address_count_0_by_30', 'fulladdress_count_0_by_30', 'address_count_0_by_14', 'fulladdress_count_0_by_14', 'fulladdress_count_3', 'address_count_3', 'address_count_0_by_7', 'fulladdress_count_0_by_7', 'age_level_address_day_since', 'age_level_address_count_30', 'address_count_1', 'fulladdress_count_1', 'age_level_address_count_14', 'fulladdress_count_0_by_3', 'address_count_0_by_3', 'fulladdress_homephone_day_since', 'fulladdress_homephone_count_30', 'ssn_dob_day_since', 'ssn_dob_count_30', 'name_dob_day_since', 'name_dob_count_30', 'ssn_age_level_day_since', 'ssn_day_since', 'ssn_age_level_count_30', 'ssn_count_30', 'ssn_name_dob_day_since', 'ssn_firstname_day_since', 'ssn_lastname_day_since', 'ssn_name_dob_count_30', 'ssn_firstname_count_30', 'ssn_lastname_count_30', 'ssn_name_day_since', 'ssn_name_count_30', 'age_level_address_count_7', 'fulladdress_homephone_count_14', 'address_count_1_by_30', 'age_level_address_count_0_by_30', 'fulladdress_count_1_by_30', 'name_dob_count_14', 'ssn_dob_count_14', 'ssn_count_14', 'ssn_age_level_count_14', 'name_count_30', 'ssn_firstname_count_14', 'ssn_name_dob_count_14', 'ssn_lastname_count_14', 'ssn_name_count_14', 'name_day_since', 'address_count_1_by_14', 'fulladdress_count_1_by_14', 'ssn_dob_count_0_by_30', 'name_dob_count_0_by_30', 'ssn_age_level_count_0_by_30', 'ssn_count_0_by_30', 'age_level_address_count_0_by_14', 'ssn_name_dob_count_0_by_30', 'ssn_firstname_count_0_by_30', 'ssn_lastname_count_0_by_30', 'name_count_14', 'ssn_name_count_0_by_30', 'fulladdress_homephone_count_0_by_30', 'fulladdress_homephone_count_7', 'homephone_count_3', 'name_dob_count_0_by_14', 'age_level_address_count_3', 'homephone_count_7', 'ssn_dob_count_0_by_14', 'name_dob_count_7', 'ssn_count_0_by_14', 'ssn_age_level_count_0_by_14', 'ssn_firstname_count_0_by_14', 'ssn_dob_count_7', 'ssn_count_7', 'ssn_name_dob_count_0_by_14', 'ssn_lastname_count_0_by_14', 'ssn_age_level_count_7', 'ssn_firstname_count_7', 'ssn_lastname_count_7', 'fulladdress_homephone_count_0_by_14', 'ssn_name_dob_count_7', 'ssn_name_count_0_by_14', 'ssn_name_count_7', 'homephone_count_14', 'name_count_7', 'name_count_0_by_30', 'address_count_0', 'fulladdress_count_0', 'fulladdress_count_1_by_7', 'address_count_1_by_7', 'name_count_0_by_14', 'age_level_address_count_0_by_7', 'homephone_count_30']

# %%
df_keep = df_top.filter(vars_keep, axis=1)
df_keep.head()
# Out:
#         address_day_since  fulladdress_day_since  address_count_30  \
# record
# 38512               365.0                  365.0                 1
# 38513               365.0                  365.0                 1
# 38514               365.0                  365.0                 1
# 38515               365.0                  365.0                 1
# 38516               365.0                  365.0                 1
#
#         fulladdress_count_30  address_count_14  fulladdress_count_14  \
# record
# 38512                      1                 1                     1
# 38513                      1                 1                     1
# 38514                      1                 1                     1
# 38515                      1                 1                     1
# 38516                      1                 1                     1
#
#         address_count_7  fulladdress_count_7  address_count_0_by_30  \
# record
# 38512                 1                    1                   30.0
# 38513                 1                    1                   30.0
# 38514                 1                    1                   30.0
# 38515                 1                    1                   30.0
# 38516                 1                    1                   30.0
#
#         fulladdress_count_0_by_30  ...  homephone_count_14  name_count_7  \
# record                             ...
# 38512                        30.0  ...                   4             1
# 38513                        30.0  ...                   6             1
# 38514                        30.0  ...                   2             1
# 38515                        30.0  ...                   1             1
# 38516                        30.0  ...                   1             1
#
#         name_count_0_by_30  address_count_0  fulladdress_count_0  \
# record
# 38512                 30.0                1                    1
# 38513                 30.0                1                    1
# 38514                 30.0                1                    1
# 38515                 30.0                1                    1
# 38516                 30.0                1                    1
#
#         fulladdress_count_1_by_7  address_count_1_by_7  name_count_0_by_14  \
# record
# 38512                        7.0                   7.0                14.0
# 38513                        7.0                   7.0                14.0
# 38514                        7.0                   7.0                14.0
# 38515                        7.0                   7.0                14.0
# 38516                        7.0                   7.0                14.0
#
#         age_level_address_count_0_by_7  homephone_count_30
# record
# 38512                              7.0                   4
# 38513                              7.0                   6
# 38514                              7.0                   2
# 38515                              7.0                   1
# 38516                              7.0                   1
#
# [5 rows x 100 columns]

# %%
df_keep.shape
# Out:
# (794997, 100)

# %%
Y.head()
# Out:
#         fraud_label
# record
# 38512             0
# 38513             0
# 38514             0
# 38515             0
# 38516             0

# %%
Y = Y.values
X = df_keep

# %%
print('time to here:', dt.datetime.now() - start_time)
# Out:
# time to here: 0:12:09.131614

# %%
print(X.shape,Y.shape)
# Out:
# (794997, 100) (794997, 1)

# %%
# I'd like to define a scoring for the wrapper that's KS, but I haven't gotten around to this yet.
# def KSscore(classifier, x,y)
#     goods =

# %%
def fdr(classifier, x, y, cutoff=detect_rate):
# Calculates FDR score for the given classifier on dataset x and y with cutoff value
# get the probability list from the given classifier
    return fdr_prob(y, classifier.predict_proba(x), cutoff)
def fdr_prob(y, y_prob, cutoff=detect_rate):
    if len(y_prob.shape) != 1:    # sometimes the proba list can contain many columns, one for each category
        y_prob = y_prob[:, -1:]   # only the last one (fraud_label==1) is used here.
    num_fraud = len(y[y == 1])    # count the total nunber of frauds   
# sort the proba list from high to low while retain the true (not predicted) fraud label
    sorted_prob = np.asarray(sorted(zip(y_prob, y), key=lambda x: x[0], reverse=True))
    cutoff_bin = sorted_prob[0:int(len(y) * cutoff), 1:]  # 3% cutoff
# return the FDR score (#fraud_in_cutoff / #total_fraud)
    return len(cutoff_bin[cutoff_bin == 1]) / num_fraud

# %%
# %%time
# If you're doing forward selection it's enough to stop at num_wrapper variables. 
# If you're doing backward selection you need to go through all the variables to get 
# a sorted list of num_wrapper variables.
nfeatures = len(X.columns)
clf = RandomForestClassifier(n_estimators=5, n_jobs=-1) # simple, fast nonlinear model for the wrapper
sfs = SFS(clf,k_features=num_wrapper,forward=True,verbose=2,scoring=fdr,cv=2,n_jobs=-1) # forward selection
# sfs = SFS(clf,k_features=1,forward=False,verbose=2,scoring=fdr,cv=2,n_jobs=-1) # backward selection
sfs.fit(X,Y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.1min finished
#
# [2022-03-15 01:27:50] Features: 1/30 -- score: 0.35425735678216963[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done  99 out of  99 | elapsed:  1.2min finished
#
# [2022-03-15 01:29:04] Features: 2/30 -- score: 0.5195020024377504[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:  1.3min finished
#
# [2022-03-15 01:30:19] Features: 3/30 -- score: 0.5581577572697196[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done  97 out of  97 | elapsed:  1.7min finished
#
# [2022-03-15 01:32:00] Features: 4/30 -- score: 0.5585930698241337[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:  1.7min finished
#
# [2022-03-15 01:33:42] Features: 5/30 -- score: 0.559376632422079[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done  95 out of  95 | elapsed:  1.8min finished
#
# [2022-03-15 01:35:31] Features: 6/30 -- score: 0.5596378199547274[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done  94 out of  94 | elapsed:  1.9min finished
#
# [2022-03-15 01:37:27] Features: 7/30 -- score: 0.5598119449764931[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done  93 out of  93 | elapsed:  2.0min finished
#
# [2022-03-15 01:39:28] Features: 8/30 -- score: 0.5594636949329619[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done  92 out of  92 | elapsed:  2.1min finished
#
# [2022-03-15 01:41:37] Features: 9/30 -- score: 0.5595507574438446[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done  91 out of  91 | elapsed:  2.3min finished
#
# [2022-03-15 01:43:54] Features: 10/30 -- score: 0.559899007487376[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:  2.3min finished
#
# [2022-03-15 01:46:13] Features: 11/30 -- score: 0.559899007487376[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=-1)]: Done  89 out of  89 | elapsed:  2.3min finished
#
# [2022-03-15 01:48:29] Features: 12/30 -- score: 0.5608566951070868[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:  2.3min finished
#
# [2022-03-15 01:50:47] Features: 13/30 -- score: 0.559899007487376[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=-1)]: Done  87 out of  87 | elapsed:  2.3min finished
#
# [2022-03-15 01:53:06] Features: 14/30 -- score: 0.5604213825526728[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=-1)]: Done  86 out of  86 | elapsed:  2.3min finished
#
# [2022-03-15 01:55:23] Features: 15/30 -- score: 0.5603343200417901[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done  85 out of  85 | elapsed:  2.7min finished
#
# [2022-03-15 01:58:04] Features: 16/30 -- score: 0.559899007487376[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:  2.7min finished
#
# [2022-03-15 02:00:44] Features: 17/30 -- score: 0.5603343200417901[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done  83 out of  83 | elapsed:  2.7min finished
#
# [2022-03-15 02:03:27] Features: 18/30 -- score: 0.5598119449764931[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=-1)]: Done  82 out of  82 | elapsed:  2.7min finished
#
# [2022-03-15 02:06:12] Features: 19/30 -- score: 0.5595507574438446[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:  2.8min finished
#
# [2022-03-15 02:09:03] Features: 20/30 -- score: 0.5598119449764931[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  2.8min finished
#
# [2022-03-15 02:11:50] Features: 21/30 -- score: 0.5599860699982587[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done  79 out of  79 | elapsed:  2.7min finished
#
# [2022-03-15 02:14:32] Features: 22/30 -- score: 0.559376632422079[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   56.3s
# [Parallel(n_jobs=-1)]: Done  78 out of  78 | elapsed:  2.8min finished
#
# [2022-03-15 02:17:23] Features: 23/30 -- score: 0.5592895699111962[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done  77 out of  77 | elapsed:  3.0min finished
#
# [2022-03-15 02:20:21] Features: 24/30 -- score: 0.5594636949329619[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:  3.0min finished
#
# [2022-03-15 02:23:23] Features: 25/30 -- score: 0.5598119449764931[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:  3.2min finished
#
# [2022-03-15 02:26:35] Features: 26/30 -- score: 0.5594636949329619[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:  3.2min finished
#
# [2022-03-15 02:29:45] Features: 27/30 -- score: 0.5589413198676649[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  73 out of  73 | elapsed:  3.1min finished
#
# [2022-03-15 02:32:54] Features: 28/30 -- score: 0.5592025074003134[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:  3.2min finished
#
# [2022-03-15 02:36:06] Features: 29/30 -- score: 0.5586801323350166[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  71 out of  71 | elapsed:  3.2min finished
# CPU times: user 3min 52s, sys: 8min 17s, total: 12min 9s
# Wall time: 1h 12min 35s
# [2022-03-15 02:39:16] Features: 30/30 -- score: 0.5588542573567822
# SequentialFeatureSelector(cv=2,
#                           estimator=RandomForestClassifier(n_estimators=5,
#                                                            n_jobs=-1),
#                           k_features=30, n_jobs=-1,
#                           scoring=<function fdr at 0x7fa911da0280>, verbose=2)

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
fig1 = plot_sfs(sfs.get_metric_dict(),kind='std_dev', figsize=(15, 6))
plt.xticks(np.arange(0, len(X.columns), step=5))
plt.ylim([0., .7])
plt.xlim(0,num_wrapper)
plt.title('Stepwise Selection')
plt.grid()
plt.savefig('FS_fdr.png')
plt.show()

# %%
vars_FS = pd.DataFrame.from_dict(sfs.get_metric_dict()).T
vars_FS
# Out:
#                                           feature_idx  \
# 1                                                (3,)
# 2                                             (3, 26)
# 3                                         (3, 26, 70)
# 4                                      (2, 3, 26, 70)
# 5                                  (2, 3, 24, 26, 70)
# 6                              (2, 3, 24, 26, 53, 70)
# 7                          (2, 3, 24, 26, 53, 59, 70)
# 8                      (2, 3, 24, 26, 47, 53, 59, 70)
# 9                  (2, 3, 24, 26, 47, 53, 59, 70, 78)
# 10             (2, 3, 24, 26, 47, 52, 53, 59, 70, 78)
# 11         (2, 3, 24, 26, 46, 47, 52, 53, 59, 70, 78)
# 12     (2, 3, 24, 26, 36, 46, 47, 52, 53, 59, 70, 78)
# 13  (2, 3, 24, 26, 28, 36, 46, 47, 52, 53, 59, 70,...
# 14  (2, 3, 24, 26, 28, 36, 46, 47, 48, 52, 53, 59,...
# 15  (2, 3, 24, 26, 28, 36, 46, 47, 48, 52, 53, 59,...
# 16  (2, 3, 24, 26, 28, 36, 46, 47, 48, 52, 53, 59,...
# 17  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 52, 53,...
# 18  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 52, 53,...
# 19  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 51, 52,...
# 20  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 51, 52,...
# 21  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 49, 51,...
# 22  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 49, 51,...
# 23  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 49, 51,...
# 24  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 49, 51,...
# 25  (2, 3, 24, 26, 28, 36, 42, 46, 47, 48, 49, 51,...
# 26  (2, 3, 24, 26, 28, 31, 36, 42, 46, 47, 48, 49,...
# 27  (2, 3, 24, 26, 28, 31, 36, 42, 46, 47, 48, 49,...
# 28  (2, 3, 24, 26, 28, 31, 36, 42, 46, 47, 48, 49,...
# 29  (2, 3, 24, 26, 28, 31, 36, 37, 42, 46, 47, 48,...
# 30  (2, 3, 24, 26, 28, 31, 36, 37, 42, 46, 47, 48,...
#
#                                    cv_scores avg_score  \
# 1    [0.351732543966568, 0.3567821695977712]  0.354257
# 2   [0.5035695629461954, 0.5354344419293052]  0.519502
# 3   [0.5455336931917116, 0.5707818213477277]  0.558158
# 4   [0.5462301932787742, 0.5709559463694933]  0.558593
# 5    [0.546752568344071, 0.5720006965000871]  0.559377
# 6   [0.5474490684311335, 0.5718265714783214]  0.559638
# 7   [0.5476231934528992, 0.5720006965000871]  0.559812
# 8   [0.5481455685181961, 0.5707818213477277]  0.559464
# 9   [0.5474490684311335, 0.5716524464565558]  0.559551
# 10  [0.5471008183876023, 0.5726971965871496]  0.559899
# 11  [0.5477973184746648, 0.5720006965000871]  0.559899
# 12  [0.5486679435834929, 0.5730454466306808]  0.560857
# 13  [0.5477973184746648, 0.5720006965000871]  0.559899
# 14  [0.5477973184746648, 0.5730454466306808]  0.560421
# 15  [0.5477973184746648, 0.5728713216089152]  0.560334
# 16  [0.5483196935399617, 0.5714783214347902]  0.559899
# 17  [0.5477973184746648, 0.5728713216089152]  0.560334
# 18  [0.5476231934528992, 0.5720006965000871]  0.559812
# 19  [0.5474490684311335, 0.5716524464565558]  0.559551
# 20  [0.5472749434093679, 0.5723489465436183]  0.559812
# 21   [0.546752568344071, 0.5732195716524464]  0.559986
# 22  [0.5471008183876023, 0.5716524464565558]  0.559377
# 23  [0.5474490684311335, 0.5711300713912589]   0.55929
# 24  [0.5469266933658367, 0.5720006965000871]  0.559464
# 25  [0.5474490684311335, 0.5721748215218527]  0.559812
# 26  [0.5472749434093679, 0.5716524464565558]  0.559464
# 27   [0.546752568344071, 0.5711300713912589]  0.558941
# 28  [0.5472749434093679, 0.5711300713912589]  0.559203
# 29  [0.5464043183005398, 0.5709559463694933]   0.55868
# 30  [0.5464043183005398, 0.5713041964130245]  0.558854
#
#                                         feature_names  ci_bound   std_dev  \
# 1                             (fulladdress_count_30,)  0.010863  0.002525
# 2            (fulladdress_count_30, ssn_dob_count_30)  0.068552  0.015932
# 3   (fulladdress_count_30, ssn_dob_count_30, homep...  0.054317  0.012624
# 4   (address_count_30, fulladdress_count_30, ssn_d...  0.053193  0.012363
# 5   (address_count_30, fulladdress_count_30, fulla...  0.054317  0.012624
# 6   (address_count_30, fulladdress_count_30, fulla...  0.052444  0.012189
# 7   (address_count_30, fulladdress_count_30, fulla...  0.052444  0.012189
# 8   (address_count_30, fulladdress_count_30, fulla...  0.048698  0.011318
# 9   (address_count_30, fulladdress_count_30, fulla...  0.052069  0.012102
# 10  (address_count_30, fulladdress_count_30, fulla...  0.055066  0.012798
# 11  (address_count_30, fulladdress_count_30, fulla...  0.052069  0.012102
# 12  (address_count_30, fulladdress_count_30, fulla...  0.052444  0.012189
# 13  (address_count_30, fulladdress_count_30, fulla...  0.052069  0.012102
# 14  (address_count_30, fulladdress_count_30, fulla...  0.054317  0.012624
# 15  (address_count_30, fulladdress_count_30, fulla...  0.053942  0.012537
# 16  (address_count_30, fulladdress_count_30, fulla...  0.049822  0.011579
# 17  (address_count_30, fulladdress_count_30, fulla...  0.053942  0.012537
# 18  (address_count_30, fulladdress_count_30, fulla...  0.052444  0.012189
# 19  (address_count_30, fulladdress_count_30, fulla...  0.052069  0.012102
# 20  (address_count_30, fulladdress_count_30, fulla...  0.053942  0.012537
# 21  (address_count_30, fulladdress_count_30, fulla...  0.056939  0.013234
# 22  (address_count_30, fulladdress_count_30, fulla...  0.052819  0.012276
# 23  (address_count_30, fulladdress_count_30, fulla...  0.050946  0.011841
# 24  (address_count_30, fulladdress_count_30, fulla...  0.053942  0.012537
# 25  (address_count_30, fulladdress_count_30, fulla...  0.053193  0.012363
# 26  (address_count_30, fulladdress_count_30, fulla...  0.052444  0.012189
# 27  (address_count_30, fulladdress_count_30, fulla...  0.052444  0.012189
# 28  (address_count_30, fulladdress_count_30, fulla...   0.05132  0.011928
# 29  (address_count_30, fulladdress_count_30, fulla...  0.052819  0.012276
# 30  (address_count_30, fulladdress_count_30, fulla...  0.053568   0.01245
#
#      std_err
# 1   0.002525
# 2   0.015932
# 3   0.012624
# 4   0.012363
# 5   0.012624
# 6   0.012189
# 7   0.012189
# 8   0.011318
# 9   0.012102
# 10  0.012798
# 11  0.012102
# 12  0.012189
# 13  0.012102
# 14  0.012624
# 15  0.012537
# 16  0.011579
# 17  0.012537
# 18  0.012189
# 19  0.012102
# 20  0.012537
# 21  0.013234
# 22  0.012276
# 23  0.011841
# 24  0.012537
# 25  0.012363
# 26  0.012189
# 27  0.012189
# 28  0.011928
# 29  0.012276
# 30   0.01245

# %%
vars_final = list(vars_FS.loc[num_wrapper, 'feature_names'])
vars_final
# Out:
# ['address_count_30',
#  'fulladdress_count_30',
#  'fulladdress_homephone_count_30',
#  'ssn_dob_count_30',
#  'name_dob_count_30',
#  'ssn_age_level_count_30',
#  'ssn_name_dob_count_30',
#  'ssn_firstname_count_30',
#  'fulladdress_homephone_count_14',
#  'name_dob_count_14',
#  'ssn_dob_count_14',
#  'ssn_count_14',
#  'ssn_age_level_count_14',
#  'ssn_firstname_count_14',
#  'ssn_name_dob_count_14',
#  'ssn_lastname_count_14',
#  'ssn_name_count_14',
#  'ssn_dob_count_0_by_30',
#  'name_dob_count_0_by_30',
#  'ssn_age_level_count_0_by_30',
#  'ssn_name_dob_count_0_by_30',
#  'ssn_firstname_count_0_by_30',
#  'ssn_lastname_count_0_by_30',
#  'fulladdress_homephone_count_0_by_30',
#  'homephone_count_3',
#  'name_dob_count_0_by_14',
#  'name_dob_count_7',
#  'ssn_age_level_count_0_by_14',
#  'ssn_firstname_count_0_by_14',
#  'ssn_name_count_0_by_14']

# %%
vars_FS.to_csv('VarsFS_3.15.csv', index=False)

# %%
sfs.subsets_
# Out:
# {1: {'feature_idx': (3,),
#   'cv_scores': array([0.35173254, 0.35678217]),
#   'avg_score': 0.35425735678216963,
#   'feature_names': ('fulladdress_count_30',)},
#  2: {'feature_idx': (3, 26),
#   'cv_scores': array([0.50356956, 0.53543444]),
#   'avg_score': 0.5195020024377504,
#   'feature_names': ('fulladdress_count_30', 'ssn_dob_count_30')},
#  3: {'feature_idx': (3, 26, 70),
#   'cv_scores': array([0.54553369, 0.57078182]),
#   'avg_score': 0.5581577572697196,
#   'feature_names': ('fulladdress_count_30',
#    'ssn_dob_count_30',
#    'homephone_count_3')},
#  4: {'feature_idx': (2, 3, 26, 70),
#   'cv_scores': array([0.54623019, 0.57095595]),
#   'avg_score': 0.5585930698241337,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'ssn_dob_count_30',
#    'homephone_count_3')},
#  5: {'feature_idx': (2, 3, 24, 26, 70),
#   'cv_scores': array([0.54675257, 0.5720007 ]),
#   'avg_score': 0.559376632422079,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'homephone_count_3')},
#  6: {'feature_idx': (2, 3, 24, 26, 53, 70),
#   'cv_scores': array([0.54744907, 0.57182657]),
#   'avg_score': 0.5596378199547274,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'ssn_lastname_count_14',
#    'homephone_count_3')},
#  7: {'feature_idx': (2, 3, 24, 26, 53, 59, 70),
#   'cv_scores': array([0.54762319, 0.5720007 ]),
#   'avg_score': 0.5598119449764931,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3')},
#  8: {'feature_idx': (2, 3, 24, 26, 47, 53, 59, 70),
#   'cv_scores': array([0.54814557, 0.57078182]),
#   'avg_score': 0.5594636949329619,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'ssn_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3')},
#  9: {'feature_idx': (2, 3, 24, 26, 47, 53, 59, 70, 78),
#   'cv_scores': array([0.54744907, 0.57165245]),
#   'avg_score': 0.5595507574438446,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'ssn_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_firstname_count_0_by_14')},
#  10: {'feature_idx': (2, 3, 24, 26, 47, 52, 53, 59, 70, 78),
#   'cv_scores': array([0.54710082, 0.5726972 ]),
#   'avg_score': 0.559899007487376,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'ssn_dob_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_firstname_count_0_by_14')},
#  11: {'feature_idx': (2, 3, 24, 26, 46, 47, 52, 53, 59, 70, 78),
#   'cv_scores': array([0.54779732, 0.5720007 ]),
#   'avg_score': 0.559899007487376,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_firstname_count_0_by_14')},
#  12: {'feature_idx': (2, 3, 24, 26, 36, 46, 47, 52, 53, 59, 70, 78),
#   'cv_scores': array([0.54866794, 0.57304545]),
#   'avg_score': 0.5608566951070868,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'ssn_name_dob_count_30',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_firstname_count_0_by_14')},
#  13: {'feature_idx': (2, 3, 24, 26, 28, 36, 46, 47, 52, 53, 59, 70, 78),
#   'cv_scores': array([0.54779732, 0.5720007 ]),
#   'avg_score': 0.559899007487376,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_firstname_count_0_by_14')},
#  14: {'feature_idx': (2, 3, 24, 26, 28, 36, 46, 47, 48, 52, 53, 59, 70, 78),
#   'cv_scores': array([0.54779732, 0.57304545]),
#   'avg_score': 0.5604213825526728,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_firstname_count_0_by_14')},
#  15: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    46,
#    47,
#    48,
#    52,
#    53,
#    59,
#    70,
#    77,
#    78),
#   'cv_scores': array([0.54779732, 0.57287132]),
#   'avg_score': 0.5603343200417901,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14')},
#  16: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    46,
#    47,
#    48,
#    52,
#    53,
#    59,
#    63,
#    70,
#    77,
#    78),
#   'cv_scores': array([0.54831969, 0.57147832]),
#   'avg_score': 0.559899007487376,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14')},
#  17: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    52,
#    53,
#    59,
#    63,
#    70,
#    77,
#    78),
#   'cv_scores': array([0.54779732, 0.57287132]),
#   'avg_score': 0.5603343200417901,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14')},
#  18: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    52,
#    53,
#    59,
#    63,
#    70,
#    71,
#    77,
#    78),
#   'cv_scores': array([0.54762319, 0.5720007 ]),
#   'avg_score': 0.5598119449764931,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14')},
#  19: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    51,
#    52,
#    53,
#    59,
#    63,
#    70,
#    71,
#    77,
#    78),
#   'cv_scores': array([0.54744907, 0.57165245]),
#   'avg_score': 0.5595507574438446,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14')},
#  20: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    51,
#    52,
#    53,
#    58,
#    59,
#    63,
#    70,
#    71,
#    77,
#    78),
#   'cv_scores': array([0.54727494, 0.57234895]),
#   'avg_score': 0.5598119449764931,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14')},
#  21: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    58,
#    59,
#    63,
#    70,
#    71,
#    77,
#    78),
#   'cv_scores': array([0.54675257, 0.57321957]),
#   'avg_score': 0.5599860699982587,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14')},
#  22: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    58,
#    59,
#    63,
#    70,
#    71,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54710082, 0.57165245]),
#   'avg_score': 0.559376632422079,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  23: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    58,
#    59,
#    63,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54744907, 0.57113007]),
#   'avg_score': 0.5592895699111962,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  24: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    58,
#    59,
#    63,
#    64,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54692669, 0.5720007 ]),
#   'avg_score': 0.5594636949329619,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'ssn_firstname_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  25: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    54,
#    58,
#    59,
#    63,
#    64,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54744907, 0.57217482]),
#   'avg_score': 0.5598119449764931,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_name_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'ssn_firstname_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  26: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    31,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    54,
#    58,
#    59,
#    63,
#    64,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54727494, 0.57165245]),
#   'avg_score': 0.5594636949329619,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_age_level_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_name_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'ssn_firstname_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  27: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    31,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    54,
#    58,
#    59,
#    63,
#    64,
#    68,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54675257, 0.57113007]),
#   'avg_score': 0.5589413198676649,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_age_level_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_name_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'ssn_firstname_count_0_by_30',
#    'fulladdress_homephone_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  28: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    31,
#    36,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    54,
#    58,
#    59,
#    60,
#    63,
#    64,
#    68,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54727494, 0.57113007]),
#   'avg_score': 0.5592025074003134,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_age_level_count_30',
#    'ssn_name_dob_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_name_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_age_level_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'ssn_firstname_count_0_by_30',
#    'fulladdress_homephone_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  29: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    31,
#    36,
#    37,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    54,
#    58,
#    59,
#    60,
#    63,
#    64,
#    68,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54640432, 0.57095595]),
#   'avg_score': 0.5586801323350166,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_age_level_count_30',
#    'ssn_name_dob_count_30',
#    'ssn_firstname_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_name_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_age_level_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'ssn_firstname_count_0_by_30',
#    'fulladdress_homephone_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')},
#  30: {'feature_idx': (2,
#    3,
#    24,
#    26,
#    28,
#    31,
#    36,
#    37,
#    42,
#    46,
#    47,
#    48,
#    49,
#    51,
#    52,
#    53,
#    54,
#    58,
#    59,
#    60,
#    63,
#    64,
#    65,
#    68,
#    70,
#    71,
#    75,
#    77,
#    78,
#    88),
#   'cv_scores': array([0.54640432, 0.5713042 ]),
#   'avg_score': 0.5588542573567822,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30',
#    'ssn_age_level_count_30',
#    'ssn_name_dob_count_30',
#    'ssn_firstname_count_30',
#    'fulladdress_homephone_count_14',
#    'name_dob_count_14',
#    'ssn_dob_count_14',
#    'ssn_count_14',
#    'ssn_age_level_count_14',
#    'ssn_firstname_count_14',
#    'ssn_name_dob_count_14',
#    'ssn_lastname_count_14',
#    'ssn_name_count_14',
#    'ssn_dob_count_0_by_30',
#    'name_dob_count_0_by_30',
#    'ssn_age_level_count_0_by_30',
#    'ssn_name_dob_count_0_by_30',
#    'ssn_firstname_count_0_by_30',
#    'ssn_lastname_count_0_by_30',
#    'fulladdress_homephone_count_0_by_30',
#    'homephone_count_3',
#    'name_dob_count_0_by_14',
#    'name_dob_count_7',
#    'ssn_age_level_count_0_by_14',
#    'ssn_firstname_count_0_by_14',
#    'ssn_name_count_0_by_14')}}

# %%
vars_final.append('index_name')
vars_final.append('y_name')
vars_final
# Out:
# ['address_count_30',
#  'fulladdress_count_30',
#  'fulladdress_homephone_count_30',
#  'ssn_dob_count_30',
#  'name_dob_count_30',
#  'ssn_age_level_count_30',
#  'ssn_name_dob_count_30',
#  'ssn_firstname_count_30',
#  'fulladdress_homephone_count_14',
#  'name_dob_count_14',
#  'ssn_dob_count_14',
#  'ssn_count_14',
#  'ssn_age_level_count_14',
#  'ssn_firstname_count_14',
#  'ssn_name_dob_count_14',
#  'ssn_lastname_count_14',
#  'ssn_name_count_14',
#  'ssn_dob_count_0_by_30',
#  'name_dob_count_0_by_30',
#  'ssn_age_level_count_0_by_30',
#  'ssn_name_dob_count_0_by_30',
#  'ssn_firstname_count_0_by_30',
#  'ssn_lastname_count_0_by_30',
#  'fulladdress_homephone_count_0_by_30',
#  'homephone_count_3',
#  'name_dob_count_0_by_14',
#  'name_dob_count_7',
#  'ssn_age_level_count_0_by_14',
#  'ssn_firstname_count_0_by_14',
#  'ssn_name_count_0_by_14',
#  'index_name',
#  'y_name']

# %%
X_final = df_keep.filter(vars_final, axis=1)
X_final.shape
# Out:
# (794997, 30)

# %%
X_final.to_csv('vars_final_3.15.csv', index=False)

# %%
print('time to here:', dt.datetime.now() - start_time)
# Out:
# time to here: 1:24:55.399302
